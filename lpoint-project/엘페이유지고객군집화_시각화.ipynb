# %% [markdown]
# # Ⅰ. 유지고객군집시각화

# %% [markdown]
# ## 가. 유지고객 군집 SQL에서 불러오기

# %% [markdown]
# ## 1. 유지_군집0
# ###    - 요일
# ###    - 채널
# ###    - 제휴사

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select de_day, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust=b.cust where 군집=0 group by de_day;")
result = cur.fetchall()
conn.commit()
conn.close()
df_w = pd.DataFrame(result)
df_w.columns=['요일','이용량']
df_w=df_w.set_index('요일')

weekday = ['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일']
df_w= df_w.loc[weekday]

df_w
# Out:
#       이용량
# 요일
# 월요일  6475
# 화요일  6116
# 수요일  5906
# 목요일  6075
# 금요일  6067
# 토요일  5702
# 일요일  5859

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select chnl_dv, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust=b.cust where 군집=0 group by chnl_dv order by chnl_dv;")
result = cur.fetchall()
conn.commit()
conn.close()
df_c = pd.DataFrame(result)
df_c.columns=['채널','이용량']
df_c
# Out:
#   채널    이용량
# 0  1   5964
# 1  2  36236

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select 군집, cop_c, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust = b.cust where 군집=0 group by cop_c order by cop_c;")
result = cur.fetchall()
conn.commit()
conn.close()
df = pd.DataFrame(result)
df.columns = ['군집', '제휴사', '수']
df
# Out:
#     군집  제휴사      수
# 0    0  A01   2212
# 1    0  A02   1642
# 2    0  A03    505
# 3    0  A04    920
# 4    0  A05     59
# 5    0  A06   4018
# 6    0  B01     26
# 7    0  C01    523
# 8    0  C02     76
# 9    0  D01    541
# 10   0  D02    159
# 11   0  E01     26
# 12   0  L00   1736
# 13   0  L01  29757

# %% [markdown]
# ## 2. 유지_군집1
# ###    - 요일
# ###    - 채널
# ###    - 제휴사

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select de_day, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust=b.cust where 군집=1 group by de_day;")
result = cur.fetchall()
conn.commit()
conn.close()
df1_w = pd.DataFrame(result)
df1_w.columns=['요일','이용량']
df1_w =  df1_w.set_index('요일')
weekday = ['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일']
df1_w= df1_w.loc[weekday]

df1_w
# Out:
#        이용량
# 요일
# 월요일  22551
# 화요일  21206
# 수요일  22113
# 목요일  21279
# 금요일  23777
# 토요일  24183
# 일요일  21798

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select chnl_dv, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust=b.cust where 군집=1 group by chnl_dv order by chnl_dv;")
result = cur.fetchall()
conn.commit()
conn.close()
df1_c = pd.DataFrame(result)
df1_c.columns=['채널','이용량']
df1_c
# Out:
#   채널    이용량
# 0  1  98462
# 1  2  58445

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select 군집, cop_c, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust = b.cust where 군집=1 group by cop_c order by cop_c;")
result = cur.fetchall()
conn.commit()
conn.close()
df1 = pd.DataFrame(result)
df1.columns = ['군집', '제휴사', '수']
df1
# Out:
#     군집  제휴사      수
# 0    1  A01  33470
# 1    1  A02  20387
# 2    1  A03  12290
# 3    1  A04  20391
# 4    1  A05   1101
# 5    1  A06  22337
# 6    1  B01    488
# 7    1  C01   5377
# 8    1  C02   1051
# 9    1  D01   6664
# 10   1  D02   2739
# 11   1  E01    172
# 12   1  L00  10372
# 13   1  L01  20068

# %% [markdown]
# ## 3. 유지_군집2
# ###    - 요일
# ###    - 채널
# ###    - 제휴사

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select de_day, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust=b.cust where 군집=2 group by de_day;")
result = cur.fetchall()
conn.commit()
conn.close()
df2_w = pd.DataFrame(result)
df2_w.columns=['요일','이용량']
df2_w=df2_w.set_index('요일')
weekday = ['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일']
df2_w= df2_w.loc[weekday]

df2_w
# Out:
#        이용량
# 요일
# 월요일  10439
# 화요일   8307
# 수요일   8728
# 목요일   8426
# 금요일   8478
# 토요일   7912
# 일요일   7978

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select chnl_dv, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust=b.cust where 군집=2 group by chnl_dv order by chnl_dv;")
result = cur.fetchall()
conn.commit()
conn.close()
df2_c = pd.DataFrame(result)
df2_c.columns=['채널','이용량']
df2_c
# Out:
#   채널    이용량
# 0  1   9328
# 1  2  50940

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select 군집, cop_c, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust = b.cust where 군집=2 group by cop_c order by cop_c;")
result = cur.fetchall()
conn.commit()
conn.close()
df2 = pd.DataFrame(result)
df2.columns = ['군집', '제휴사', '수']
df2
# Out:
#     군집  제휴사      수
# 0    2  A01   3505
# 1    2  A02   2550
# 2    2  A03    747
# 3    2  A04   1368
# 4    2  A05    179
# 5    2  A06  41686
# 6    2  B01     92
# 7    2  C01    728
# 8    2  C02    136
# 9    2  D01   1273
# 10   2  D02    329
# 11   2  E01     20
# 12   2  L00   3155
# 13   2  L01   4500

# %% [markdown]
# ## 4. 유지_군집3
# ###    - 요일
# ###    - 채널
# ###    - 제휴사

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select de_day, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust=b.cust where 군집=3 group by de_day;")
result = cur.fetchall()
conn.commit()
conn.close()
df3_w = pd.DataFrame(result)
df3_w.columns=['요일','이용량']
df3_w=df3_w.set_index('요일')
weekday = ['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일']
df3_w= df3_w.loc[weekday]

df3_w
# Out:
#      이용량
# 요일
# 월요일  214
# 화요일  216
# 수요일  201
# 목요일  205
# 금요일  191
# 토요일  184
# 일요일  200

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select chnl_dv, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust=b.cust where 군집=3 group by chnl_dv order by chnl_dv;")
result = cur.fetchall()
conn.commit()
conn.close()
df3_c = pd.DataFrame(result)
df3_c.columns=['채널','이용량']
df3_c
# Out:
#   채널   이용량
# 0  2  1411

# %%
df3_c_try = pd.DataFrame({'채널':['1','2']})

df3_c_try["이용량"] = np.nan

df3_c_try=df3_c_try.set_index('채널')
for i in range(len(df3_c)):
    df3_c_try.loc[[df3_c['채널'][i]],['이용량']]=df3_c['이용량'][i]
df3_c_try=df3_c_try.fillna(0)
df3_c_try=df3_c_try.astype(int)
df3_c_try.reset_index(inplace=True)
df3_c_try
# Out:
#   채널   이용량
# 0  1     0
# 1  2  1411

# %%
import pandas as pd
import pymysql
conn = pymysql.connect(host='127.0.0.1', user='root', password='lpoint', db='lpoint', charset='utf8')
cur = conn.cursor()
cur.execute("select 군집, cop_c, count(*) from 엘페이유지고객군집화 a inner join 엘페이이용_view b on a.cust = b.cust where 군집=3 group by cop_c order by cop_c;")
result = cur.fetchall()
conn.commit()
conn.close()
df3 = pd.DataFrame(result)
df3.columns = ['군집', '제휴사', '수']
df3
# Out:
#    군집  제휴사     수
# 0   3  A06     1
# 1   3  D01     6
# 2   3  L01  1404

# %%
cop_list = df['제휴사'].values.tolist()

df3_try = pd.DataFrame({'제휴사': cop_list})

df3_try["수"] = np.nan

df3_try=df3_try.set_index('제휴사')
for i in range(len(df3)):
    df3_try.loc[[df3['제휴사'][i]],['수']]=df3['수'][i]
df3_try=df3_try.fillna(0)
df3_try=df3_try.astype(int)
df3_try.reset_index(inplace=True)
df3_try
# Out:
#     제휴사     수
# 0   A01     0
# 1   A02     0
# 2   A03     0
# 3   A04     0
# 4   A05     0
# 5   A06     1
# 6   B01     0
# 7   C01     0
# 8   C02     0
# 9   D01     6
# 10  D02     0
# 11  E01     0
# 12  L00     0
# 13  L01  1404

# %% [markdown]
# ## 나. 시각화

# %% [markdown]
# ## 1.군집별 요일별 이용량

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager

f_path = "C:/windows/Fonts/malgun.ttf"
font_manager.FontProperties(fname=f_path).get_name()
rc('font', family='Malgun Gothic')
parameters = {'axes.labelsize': 40,
          'axes.titlesize': 30}
plt.rcParams.update(parameters)
plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')

plt.title("군집0",size=30)
plt.xticks(size=30)
plt.yticks(size=30)
plt.xlabel('요일',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df_w.index,df_w['이용량'], color = ['red','navy','navy','navy','navy','navy','navy'], alpha=0.5)
plt.savefig('유지요일별군집0.png')



plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')
plt.title("군집1",size=30)
plt.xticks(size=30)
plt.yticks(size=30)
plt.xlabel('요일',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df1_w.index,df1_w['이용량'],color = ['navy','navy','navy','navy','red','red','navy'], alpha=0.5)
plt.savefig('유지요일별군집1.png')



plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')
plt.title("군집2",size=30)
plt.xticks(size=30)
plt.yticks(size=30)
plt.xlabel('요일',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df2_w.index,df2_w['이용량'], color = ['red','navy','navy','navy','navy','navy','navy'], alpha=0.5)
plt.savefig('유지요일별군집2.png')




plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')
plt.title("군집3",size=30)
plt.xticks(size=30)
plt.yticks(size=30)
plt.xlabel('요일',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df3_w.index,df3_w['이용량'], color = ['red','red','navy','navy','navy','navy','navy'], alpha=0.5)
plt.savefig('유지요일별군집3.png')

# %% [markdown]
# ## 2.군집별 채널별 이용량

# %% [markdown]
# ### (1) 1을 오프라인으로 2를 온라인으로 변환

# %%
for i in range(len(df_c)):
    if df_c['채널'][i] == '1':
        df_c['채널'][i] = '오프라인'
    else:
        df_c['채널'][i] = '온라인'
for i in range(len(df_c)):
    if df1_c['채널'][i] == '1':
        df1_c['채널'][i] = '오프라인'
    else:
        df1_c['채널'][i] = '온라인'
        
for i in range(len(df_c)):
    if df2_c['채널'][i] == '1':
        df2_c['채널'][i] = '오프라인'
    else:
        df2_c['채널'][i] = '온라인'


for i in range(len(df3_c)):
    if df3_c['채널'][i] == '1':
        df3_c['채널'][i] = '오프라인'
    else:
        df3_c['채널'][i] = '온라인'
        
df3_c
# Out:
# <ipython-input-146-b83bb15c9db8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['채널'][i] = '오프라인'
# <ipython-input-146-b83bb15c9db8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['채널'][i] = '온라인'
# <ipython-input-146-b83bb15c9db8>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_c['채널'][i] = '오프라인'
# <ipython-input-146-b83bb15c9db8>:10: SettingWithCopyWarning:
# ...

# %% [markdown]
# ### (2) 시각화

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager

f_path = "C:/windows/Fonts/malgun.ttf"
font_manager.FontProperties(fname=f_path).get_name()
rc('font', family='Malgun Gothic')
parameters = {'axes.labelsize': 10,
          'axes.titlesize': 15}
plt.rcParams.update(parameters)
plt.figure(figsize=(16,8))
# plt.suptitle("군집별 채널별 이용량", size=30)

plt.grid(axis='y', linestyle='--')
plt.xticks(np.arange(0,24,1))
plt.title("군집0",size=30)
plt.xticks(size=30)
plt.yticks(size=30)
plt.xlabel('채널',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df_c['채널'],df_c['이용량'], color=['navy','red'], alpha=0.5)
plt.savefig('유지온오프라인별군집0.png')


plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')
plt.xticks(np.arange(0,24,1))
plt.title("군집1",size=30)
plt.xticks(size=30)
plt.yticks(size=30)
plt.xlabel('채널',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df1_c['채널'],df1_c['이용량'], color=['red','navy'], alpha=0.5)
plt.savefig('유지온오프라인별군집1.png')



plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')
plt.title("군집2",size=30)
plt.xticks(size=30)
plt.yticks(size=30)
plt.xlabel('채널',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df2_c['채널'],df2_c['이용량'], color=['navy','red'], alpha=0.5)
plt.savefig('유지온오프라인별군집2.png')



plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')
plt.title("군집3",size=30)
plt.xticks(size=30)
plt.yticks(size=30)
plt.xlabel('채널',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df3_c_try['채널'],df3_c_try['이용량'], color='red', alpha=0.5)
plt.savefig('유지온오프라인별군집3.png')

# %% [markdown]
# ## 3.군집별 제휴사별 이용량

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager

f_path = "C:/Users/ASIAE_10/Downloads/NanumFontSetup_TTF_SQUARE/NanumSquareEB.ttf"
font_manager.FontProperties(fname=f_path).get_name()
# rc('font', family='Malgun Gothic')
parameters = {'axes.labelsize': 40,
          'axes.titlesize': 30}
plt.rcParams.update(parameters)
plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')

# plt.suptitle("군집별 이용제휴사 분포", size=30)
plt.title("군집0",size=30)
plt.xticks(size=25)
plt.yticks(size=30)
plt.xlabel('제휴사',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df['제휴사'],df['수'],color = ['navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','red'], alpha=0.5)
plt.savefig('유지제휴사별군집0.png')



plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')
plt.title("군집1",size=30)
plt.xticks(size=25)
plt.yticks(size=30)
plt.xlabel('제휴사',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df1['제휴사'],df1['수'],color = ['red','navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','navy'], alpha=0.5)
plt.savefig('유지제휴사별군집1.png')



plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')
plt.title("군집2",size=30)
plt.xticks(size=25)
plt.yticks(size=30)
plt.xlabel('제휴사',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df2['제휴사'],df2['수'],color = ['navy','navy','navy','navy','navy','red','navy','navy','navy','navy','navy','navy','navy','navy'], alpha=0.5)
plt.savefig('유지제휴사별군집2.png')




plt.figure(figsize=(16,8))
plt.grid(axis='y', linestyle='--')
plt.title("군집3",size=30)
plt.xticks(size=25)
plt.yticks(size=30)
plt.xlabel('제휴사',size=30)
plt.ylabel('이용량',size=30)
plt.bar(df3_try['제휴사'],df3_try['수'],color=['navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','navy','red'], alpha = 0.5)
plt.savefig('유지제휴사별군집3.png')
