# %% [markdown]
# # Ⅰ. EDA
# ##    - powerbi에서 나온 데이터를 통해 시각화 함

# %% [markdown]
# ## 가. 데이터탐색_상품구매정보

# %% [markdown]
# ### 1. 성별별 고객분포

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

ratio = [68.7, 31.3]
labels = ['여성', '남성']
colors = ['#F15F5F', '#D5D5D5']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.title('성별별 고객분포', size = 18)
plt.show()

# %% [markdown]
# ### 2. 연령대별 고객분포

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

ratio = [10.6, 25.2, 34.2, 19.8, 7.6, 2.5]
labels = ['20대', '30대', '40대', '50대', '60대', '70대']
colors = ['#D5D5D5', '#D5D5D5','#F15F5F', '#E5D85C', '#D5D5D5', '#D5D5D5']
explode = [0, 0, 0, 0, 0, 0.2]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops, explode=explode)
plt.title('연령대별 고객분포', size = 18)
plt.show()

# %% [markdown]
# ### 3. 거주지별 고객분포

# %%
import matplotlib.pyplot as plt
import squarify

plt.style.use('default')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기
plt.rcParams['figure.figsize'] = (4, 4)

sizes = [1.56, 0.28, 1.97, 5.92, 1.97, 3.81, 0.64, 2.43, 2.15, 27.32, 6.32, 2.68, 3.03, 3.10, 2.12, 8.45, 26.25]
labels = ['Z01' ,'Z02', 'Z03', 'Z04', 'Z05', 'Z06' ,'Z07', 'Z08', 'Z09', 'Z10', 'Z11', 'Z12', 'Z13', 'Z14', 'Z15', 'Z16', 'Z17']
colors = ['#FFA7A7', '#FFC19E', '#FAED7D', '#CEF279','#B7F0B1', '#B2EBF4', '#B2CCFF','#B5B2FF', '#D1B2FF','#F15F5F','#FFB2F5','#FFB2D9','#D5D5D5','#BDBDBD', '#F2CB61', '#86E57F','#E5D85C']

squarify.plot(sizes, label=labels, color=colors, bar_kwargs=dict(linewidth=3, edgecolor="#eee"))
plt.title('거주지별 고객분포', size = 18)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 나. 데이터탐색_엘페이이용

# %% [markdown]
# ### 1. 성별별 고객분포

# %%
# 데이터탐색_엘페이이용1

import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기


ratio = [66.3, 33.7]
labels = ['여성', '남성']
colors = ['#F15F5F', '#D5D5D5']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.title('성별별 고객분포', size = 18)
plt.show()

# %% [markdown]
# ### 2. 연령대별 고객분포

# %%
# 데이터탐색_엘페이이용2

import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기


ratio = [9.2, 32.2, 41.7, 14.3, 2.2, 0.4]
labels = ['20대', '30대', '40대', '50대', '60대', '70대']
colors = ['#D5D5D5', '#D5D5D5','#F15F5F', '#E5D85C', '#D5D5D5', '#D5D5D5']
explode = [0, 0, 0, 0, 0.4, 0.2]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops, explode=explode)
plt.title('연령대별 고객분포', size = 18)
plt.show()

# %% [markdown]
# ### 3. 거주지별 고객분포

# %%
import matplotlib.pyplot as plt
import squarify

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 4)
plt.rcParams['font.size'] = 12 # 글자 크기
plt.rcParams['font.family'] = 'Malgun Gothic'

sizes = [1.00, 0.28, 1.74, 5.17, 1.10, 3.23, 0.49, 1.76, 1.31, 26.67, 4.92, 1.61, 2.76, 2.74, 1.85, 9.56 ,33.81]
labels = ['Z01' ,'Z02', 'Z03', 'Z04', 'Z05', 'Z06' ,'Z07', 'Z08', 'Z09', 'Z10', 'Z11', 'Z12', 'Z13', 'Z14', 'Z15', 'Z16', 'Z17']
colors = ['#FFA7A7', '#FFC19E', '#FAED7D', '#CEF279','#B7F0B1', '#B2EBF4', '#B2CCFF','#B5B2FF', '#D1B2FF', '#E5D85C','#FFB2F5','#FFB2D9','#D5D5D5','#BDBDBD', '#F2CB61', '#86E57F','#F15F5F']

squarify.plot(sizes, label=labels, color=colors, bar_kwargs=dict(linewidth=3, edgecolor="#eee"))
plt.title('거주지별 고객분포', size = 18)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 다. 데이터탐색_제휴사이용정보

# %% [markdown]
# ### 1. 성별별 고객분포

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

ratio = [67.1, 32.9]
labels = ['여성', '남성']
colors = ['#F15F5F', '#D5D5D5']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.title('성별별 고객분포', size = 18)
plt.show()

# %% [markdown]
# ### 2. 연령대별 고객분포

# %%
# 데이터탐색_제휴사이용2

import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

ratio = [15.3, 29.0, 36.1, 15.3, 3.5, 0.9]
labels = ['20대', '30대', '40대', '50대', '60대', '70대']
colors = ['#D5D5D5', '#D5D5D5','#F15F5F', '#E5D85C', '#D5D5D5', '#D5D5D5']
explode = [0, 0, 0, 0, 0.4, 0.2]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops, explode=explode)
plt.title('연령대별 고객분포', size = 18)
plt.show()

# %% [markdown]
# ### 3. 거주지별 고객분포

# %%
import matplotlib.pyplot as plt
import squarify

plt.style.use('default')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기
plt.rcParams['figure.figsize'] = (4, 4)

sizes = [1.32, 0.30, 1.97, 5.69, 1.60, 3.70, 0.54, 2.23, 1.91, 26.97, 6.05, 2.31, 2.83, 3.15, 2.16, 8.74, 28.55]
labels = ['Z01' ,'Z02', 'Z03', 'Z04', 'Z05', 'Z06' ,'Z07', 'Z08', 'Z09', 'Z10', 'Z11', 'Z12', 'Z13', 'Z14', 'Z15', 'Z16', 'Z17']
colors = ['#FFA7A7', '#FFC19E', '#FAED7D', '#CEF279','#B7F0B1', '#B2EBF4', '#B2CCFF','#B5B2FF', '#D1B2FF', '#E5D85C','#FFB2F5','#FFB2D9','#D5D5D5','#BDBDBD', '#F2CB61', '#86E57F','#F15F5F']

squarify.plot(sizes, label=labels, color=colors, bar_kwargs=dict(linewidth=3, edgecolor="#eee"))
plt.title('거주지별 고객분포', size = 18)
plt.axis('off')
plt.show()

# %% [markdown]
# # Ⅱ. 문제정의

# %% [markdown]
# ## 가. 가설1

# %% [markdown]
# ### 1. 일반 이용 고객의 제휴사 선호도

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

ratio = [16.0, 54.2, 20.7, 7.2, 0.2, 1.7]
labels = ['AO1', 'AO2', 'AO3', 'AO4', 'AO5', 'AO6']
colors = ['#D5D5D5', '#F15F5F','#E5D85C', '#D5D5D5', '#D5D5D5', '#D5D5D5']
explode = [0, 0, 0, 0, 0.2, 0.4]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops, explode=explode)
plt.title('일반 이용 고객의 제휴사 선호도', size = 18)
plt.show()

# %% [markdown]
# ### 2. 엘페이 이용 고객의 제휴사 선호도

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

ratio = [23.7, 13.9, 7.2, 12.8, 1.2, 41.2]
labels = ['AO1', 'AO2', 'AO3', 'AO4', 'AO5', 'AO6']
colors = ['#D5D5D5', '#F15F5F','#E5D85C', '#D5D5D5', '#D5D5D5', '#D5D5D5']
explode = [0, 0, 0, 0, 0.2, 0]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops, explode=explode)
plt.title('엘페이 이용 고객의 제휴사 선호도', size = 18)
plt.show()

# %% [markdown]
# ## 나. 가설 2

# %% [markdown]
# ### 1. 연령별 엘페이 사용자

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

ratio = [816,2867,3718,1272,200,33]
labels = ['20대', '30대', '40대', '50대', '60대', '70대']
colors = ['#D5D5D5', '#D5D5D5','#F15F5F', '#D5D5D5', '#D5D5D5', '#D5D5D5']
explode = [0, 0, 0, 0, 0.4, 0.2]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops, explode=explode)
plt.title('연령별 엘페이사용자', size = 18)
plt.show()

# %% [markdown]
# ### 2. 연령별 엘페이 이용금액

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

ratio = [1214393956,5984339499,10196101394,3541996706,483989292,56930792]
labels = ['20대', '30대', '40대', '50대', '60대', '70대']
colors = ['#D5D5D5', '#D5D5D5','#F15F5F', '#D5D5D5', '#D5D5D5', '#D5D5D5']
explode = [0, 0, 0, 0, 0.4, 0.2]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops, explode=explode)
plt.title('연령별 엘페이 이용금액', size = 18)
plt.show()

# %% [markdown]
# ### 3. 연령별 엘페이 이용건수

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

ratio = [26491,99874,163346,55622,7232,619]
labels = ['20대', '30대', '40대', '50대', '60대', '70대']
colors = ['#D5D5D5', '#D5D5D5','#F15F5F', '#D5D5D5', '#D5D5D5', '#D5D5D5']
explode = [0, 0, 0, 0, 0.4, 0.2]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops, explode=explode)
plt.title('연령별 엘페이 이용건수', size = 18)
plt.show()

# %% [markdown]
# ## 다. 가설3

# %% [markdown]
# ### 1. 월별 판초콜릿 판매금액

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

levels = ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']
counts = [5630187, 8879103, 6045974, 3060418, 3168193, 1696274, 1410020, 1344268, 2582873, 3405521, 3624521, 4081737]
color = ['#D5D5D5', '#B2CCFF','#D5D5D5', '#D5D5D5', '#D5D5D5','#D5D5D5', '#D5D5D5', '#D5D5D5','#D5D5D5', '#D5D5D5', '#D5D5D5','#D5D5D5']
plt.figure(figsize=(10,5))

plt.bar(levels, counts, color=color)

plt.title('월별 판초콜릿 판매금액\n', size = 18)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### 2. 월별 사탕/캔디 판매금액

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

levels = ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']
counts = [86890, 167318, 280791, 237801, 194645, 105922, 104150, 164460, 211900, 99820, 73172, 149320]
color = ['#D5D5D5', '#D5D5D5', '#8fd9b6', '#D5D5D5', '#D5D5D5','#D5D5D5', '#D5D5D5', '#D5D5D5','#D5D5D5', '#D5D5D5', '#D5D5D5','#D5D5D5']
plt.figure(figsize=(10,5))

plt.bar(levels, counts, color=color)

plt.title('월별 사탕/캔디 판매금액\n', size = 18)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### 3. 월별 레드와인 판매금액

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12 # 글자 크기

levels = ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']
counts = [39853340, 30079780, 34291200, 31264740, 28003580, 28138260, 22587430, 28759840, 39976200, 28826175, 17664610, 53154580]
color = ['#D5D5D5', '#D5D5D5', '#D5D5D5', '#D5D5D5','#D5D5D5', '#D5D5D5', '#D5D5D5','#D5D5D5', '#D5D5D5', '#D5D5D5','#D5D5D5','#ff9999']
plt.figure(figsize=(10,5))

plt.bar(levels, counts, color=color)

plt.title('월별 레드와인 판매금액\n', size = 18)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
